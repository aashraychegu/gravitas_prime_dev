# %%
from coredldev.finders.distance_scaling.h5 import h5Finder
from coredldev.sources.distance_scaling.h5 import h5Source

# %%
h5Finder(sync=True,shiftpercents=[0],angles=[(0,0,0)],distances = [1])
# Out:
#
# done!
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0001
#  Found R01
#  Found R02
# Found BAM:0002
#  Found R01
#  Found R02
# Found BAM:0003
#  Found R01
#  Found R02
# Found BAM:0004
#  Found R01
#  Found R02
# Found BAM:0005
#  Found R01
#  Found R02
# Found BAM:0006
#  Found R01
#  Found R02
# Found BAM:0007
#  Found R01
#  Found R02
# Found BAM:0008
#  Found R01
# Found BAM:0009
#  Found R01
#  Found R02
# Found BAM:0010
#  Found R01
#  Found R02
# Found BAM:0011
#  Found R01
#  Found R02
# Found BAM:0012
#  Found R01
#  Found R02
# Found BAM:0013
#  Found R01
#  Found R02
# Found BAM:0014
#  Found R01
#  Found R02
# Found BAM:0015
#  Found R01
#  Found R02
# Found BAM:0016
#  Found R01
#  Found R02
# Found BAM:0017
#  Found R01
#  Found R02
# Found BAM:0018
#  Found R01
#  Found R02
# Found BAM:0019
#  Found R01
#  Found R02
# Found BAM:0020
#  Found R01
#  Found R02
# Found BAM:0021
#  Found R01
#  Found R02
# Found BAM:0022
#  Found R01
# Found BAM:0023
#  Found R01
#  Found R02
# Found BAM:0024
#  Found R01
# Found BAM:0025
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0026
#  Found R01
# Found BAM:0027
#  Found R01
# Found BAM:0028
#  Found R01
# Found BAM:0029
#  Found R01
# Found BAM:0030
#  Found R01
# Found BAM:0031
#  Found R01
# Found BAM:0032
#  Found R01
# Found BAM:0033
#  Found R01
# Found BAM:0034
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0035
#  Found R01
#  Found R02
# Found BAM:0036
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0037
#  Found R01
# Found BAM:0038
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0039
#  Found R01
# Found BAM:0040
#  Found R01
# Found BAM:0041
#  Found R01
#  Found R02
# Found BAM:0042
#  Found R01
#  Found R02
# Found BAM:0043
#  Found R01
#  Found R02
# Found BAM:0044
#  Found R01
#  Found R02
# Found BAM:0045
#  Found R01
#  Found R02
# Found BAM:0046
#  Found R01
#  Found R02
# Found BAM:0047
#  Found R01
#  Found R02
# Found BAM:0048
#  Found R01
#  Found R02
# Found BAM:0049
#  Found R01
#  Found R02
# Found BAM:0050
#  Found R01
#  Found R02
# Found BAM:0051
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0052
#  Found R01
#  Found R02
# Found BAM:0053
#  Found R01
#  Found R02
# Found BAM:0054
#  Found R01
#  Found R02
# Found BAM:0055
#  Found R01
#  Found R02
# Found BAM:0056
#  Found R01
#  Found R02
# Found BAM:0057
#  Found R01
#  Found R02
# Found BAM:0058
#  Found R01
#  Found R02
# Found BAM:0059
#  Found R01
#  Found R02
# Found BAM:0060
#  Found R01
#  Found R02
# Found BAM:0061
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0062
#  Found R01
# Found BAM:0063
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0064
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
#  Found R07
#  Found R08
#  Found R09
# Found BAM:0065
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0066
#  Found R01
# Found BAM:0067
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0068
#  Found R01
# Found BAM:0069
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0070
#  Found R01
#  Found R02
# Found BAM:0071
#  Found R01
#  Found R02
# Found BAM:0072
#  Found R01
#  Found R02
# Found BAM:0073
#  Found R01
# Found BAM:0074
#  Found R01
# Found BAM:0075
#  Found R01
# Found BAM:0076
#  Found R01
# Found BAM:0077
#  Found R01
# Found BAM:0078
#  Found R01
# Found BAM:0079
#  Found R01
# Found BAM:0080
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0081
#  Found R01
# Found BAM:0082
#  Found R01
# Found BAM:0083
#  Found R01
# Found BAM:0084
#  Found R01
# Found BAM:0085
#  Found R01
# Found BAM:0086
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
# Found BAM:0087
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0088
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0089
#  Found R01
#  Found R02
# Found BAM:0090
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0091
#  Found R01
#  Found R02
# Found BAM:0092
#  Found R01
#  Found R02
# Found BAM:0093
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0094
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0095
#  Found R01
#  Found R02
# Found BAM:0096
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
#  Found R07
#  Found R08
#  Found R09
#  Found R10
# Found BAM:0097
#  Found R01
# Found BAM:0098
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0099
# File metadata_main.txt not found
#  Found no runs R?? folders in /mnt/c/Users/aashr/Desktop/research/Core_DB_Pytorch_Dataloaders_System/coredldev/_resources/CoRe_DB/BAM_0100
# Found BAM:0100
# skip core_database_index, not a DB key
# git-pull BAM_0001 ...
#
# done!
# git-pull BAM_0002 ...
#
# done!
# git-pull BAM_0003 ...
#
# done!
# git-pull BAM_0004 ...
#
# done!
# git-pull BAM_0005 ...
#
# done!
# git-pull BAM_0006 ...
#
# done!
# git-pull BAM_0007 ...
#
# done!
# git-pull BAM_0008 ...
#
# done!
# git-pull BAM_0009 ...
#
# done!
# git-pull BAM_0010 ...
#
# done!
# git-pull BAM_0011 ...
#
# done!
# git-pull BAM_0012 ...
#
# done!
# git-pull BAM_0013 ...
#
# done!
# git-pull BAM_0014 ...
#
# done!
# git-pull BAM_0015 ...
#
# done!
# git-pull BAM_0016 ...
#
# done!
# git-pull BAM_0017 ...
#
# done!
# git-pull BAM_0018 ...
#
# done!
# git-pull BAM_0019 ...
#
# done!
# git-pull BAM_0020 ...
#
# done!
# git-pull BAM_0021 ...
#
# done!
# git-pull BAM_0022 ...
#
# done!
# git-pull BAM_0023 ...
#
# done!
# git-pull BAM_0024 ...
#
# done!
# git-pull BAM_0025 ...
#
# done!
# git-pull BAM_0026 ...
#
# done!
# git-pull BAM_0027 ...
#
# done!
# git-pull BAM_0028 ...
#
# done!
# git-pull BAM_0029 ...
#
# done!
# git-pull BAM_0030 ...
#
# done!
# git-pull BAM_0031 ...
#
# done!
# git-pull BAM_0032 ...
#
# done!
# git-pull BAM_0033 ...
#
# done!
# git-pull BAM_0034 ...
#
# done!
# git-pull BAM_0035 ...
#
# done!
# git-pull BAM_0036 ...
#
# done!
# git-pull BAM_0037 ...
#
# done!
# git-pull BAM_0038 ...
#
# done!
# git-pull BAM_0039 ...
#
# done!
# git-pull BAM_0040 ...
#
# done!
# git-pull BAM_0041 ...
#
# done!
# git-pull BAM_0042 ...
#
# done!
# git-pull BAM_0043 ...
#
# done!
# git-pull BAM_0044 ...
#
# done!
# git-pull BAM_0045 ...
#
# done!
# git-pull BAM_0046 ...
#
# done!
# git-pull BAM_0047 ...
#
# done!
# git-pull BAM_0048 ...
#
# done!
# git-pull BAM_0049 ...
#
# done!
# git-pull BAM_0050 ...
#
# done!
# git-pull BAM_0051 ...
#
# done!
# git-pull BAM_0052 ...
#
# done!
# git-pull BAM_0053 ...
#
# done!
# git-pull BAM_0054 ...
#
# done!
# git-pull BAM_0055 ...
#
# done!
# git-pull BAM_0056 ...
#
# done!
# git-pull BAM_0057 ...
#
# done!
# git-pull BAM_0058 ...
#
# done!
# git-pull BAM_0059 ...
#
# done!
# git-pull BAM_0060 ...
#
# done!
# git-pull BAM_0061 ...
#
# done!
# git-pull BAM_0062 ...
#
# done!
# git-pull BAM_0063 ...
#
# done!
# git-pull BAM_0064 ...
#
# done!
# git-pull BAM_0065 ...
#
# done!
# git-pull BAM_0066 ...
#
# done!
# git-pull BAM_0067 ...
#
# done!
# git-pull BAM_0068 ...
#
# done!
# git-pull BAM_0069 ...
#
# done!
# git-pull BAM_0070 ...
#
# done!
# git-pull BAM_0071 ...
#
# done!
# git-pull BAM_0072 ...
#
# done!
# git-pull BAM_0073 ...
#
# done!
# git-pull BAM_0074 ...
#
# done!
# git-pull BAM_0075 ...
#
# done!
# git-pull BAM_0076 ...
#
# done!
# git-pull BAM_0077 ...
#
# done!
# git-pull BAM_0078 ...
#
# done!
# git-pull BAM_0079 ...
#
# done!
# git-pull BAM_0080 ...
#
# done!
# git-pull BAM_0081 ...
#
# done!
# git-pull BAM_0082 ...
#
# done!
# git-pull BAM_0083 ...
#
# done!
# git-pull BAM_0084 ...
#
# done!
# git-pull BAM_0085 ...
#
# done!
# git-pull BAM_0086 ...
#
# done!
# git-pull BAM_0087 ...
#
# done!
# git-pull BAM_0088 ...
#
# done!
# git-pull BAM_0089 ...
#
# done!
# git-pull BAM_0090 ...
#
# done!
# git-pull BAM_0091 ...
#
# done!
# git-pull BAM_0092 ...
#
# done!
# git-pull BAM_0093 ...
#
# done!
# git-pull BAM_0094 ...
#
# done!
# git-pull BAM_0095 ...
#
# done!
# git-pull BAM_0096 ...
#
# done!
# git-pull BAM_0097 ...
#
# done!
# git-pull BAM_0098 ...
#
# done!
# git-pull BAM_0099 ...
#
# done!
# git-pull BAM_0100 ...
#  Could not pull
#
# Errors logged to '/mnt/c/Users/aashr/Desktop/research/Core_DB_Pytorch_Dataloaders_System/coredldev/_resources/CoRe_DB/BAM_0100/.git/lfs/logs/20250326T172516.848200117.log'.
# Use `git lfs logs last` to view the log.
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0101.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0101'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0102.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0102'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0103.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0103'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0104.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0104'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0105.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0105'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0106.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0106'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0107.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0107'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0108.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0108'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0109.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0109'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0110.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0110'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0111.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0111'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0112.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0112'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0113.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0113'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0114.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0114'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0115.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0115'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0116.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0116'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0117.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0117'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0118.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0118'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0119.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0119'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0120.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0120'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0121.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0121'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0122.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0122'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0123.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0123'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0124.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0124'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0125.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0125'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0126.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0126'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0127.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0127'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0128.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0128'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0129.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0129'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0130.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0130'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0131.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0131'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0132.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0132'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0133.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0133'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0134.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0134'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0135.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0135'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0136.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0136'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0137.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0137'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0138.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0138'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0139.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0139'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0140.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0140'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0141.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0141'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0142.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0142'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0143.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0143'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0144.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0144'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0145.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0145'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0146.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0146'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/BAM_0147.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'BAM_0147'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0001.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0001'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0002.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0002'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0003.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0003'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0004.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0004'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0005.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0005'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0006.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0006'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0007.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0007'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0008.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0008'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0009.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0009'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0010.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0010'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0011.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0011'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0012.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0012'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0013.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0013'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0014.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0014'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0015.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0015'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0016.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0016'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0017.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0017'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0018.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0018'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0019.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0019'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0020.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0020'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0021.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0021'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0022.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0022'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0023.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0023'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0024.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0024'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0025.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0025'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0026.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0026'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0027.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0027'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0028.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0028'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0029.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0029'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0030.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0030'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0031.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0031'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0032.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0032'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0033.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0033'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0034.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0034'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0035.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0035'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0036.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0036'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0037.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0037'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0038.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0038'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0039.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0039'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0040.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0040'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0041.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0041'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0042.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0042'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0043.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0043'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0044.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0044'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0045.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0045'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0046.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0046'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0047.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0047'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0048.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0048'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0049.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0049'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0050.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0050'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0051.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0051'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0052.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0052'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0053.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0053'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0054.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0054'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0055.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0055'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0056.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0056'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0057.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0057'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0058.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0058'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0059.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0059'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0060.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0060'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0061.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0061'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0062.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0062'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0063.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0063'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0064.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0064'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0065.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0065'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0066.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0066'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0067.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0067'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0068.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0068'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0069.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0069'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0070.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0070'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0071.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0071'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0072.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0072'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0073.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0073'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0074.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0074'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0075.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0075'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0076.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0076'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0077.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0077'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0078.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0078'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0079.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0079'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0080.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0080'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0081.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0081'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0082.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0082'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0083.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0083'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0084.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0084'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0085.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
# ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0089'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0090.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0090'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0091.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0091'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0092.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0092'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0093.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0093'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0094.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0094'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0095.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0095'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0096.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0096'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0097.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0097'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0098.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0098'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0099.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0099'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0100.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0100'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0101.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0101'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0102.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0102'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0103.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0103'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0104.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0104'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0105.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0105'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0106.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0106'...
#
# done!
# git-clone https://core-gitlfs.tpi.uni-jena.de/core_database/THC_0107.git ...
#  WARNING: `git lfs clone` is deprecated and will not be updated
#           with new flags from `git clone`
#
# `git clone` has been updated in upstream Git to have comparable
# speeds to `git lfs clone`.
# Cloning into 'THC_0107'...
#
# done!
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0001
#  Found R01
#  Found R02
# Found BAM:0002
#  Found R01
#  Found R02
# Found BAM:0003
#  Found R01
#  Found R02
# Found BAM:0004
#  Found R01
#  Found R02
# Found BAM:0005
#  Found R01
#  Found R02
# Found BAM:0006
#  Found R01
#  Found R02
# Found BAM:0007
#  Found R01
#  Found R02
# Found BAM:0008
#  Found R01
# Found BAM:0009
#  Found R01
#  Found R02
# Found BAM:0010
#  Found R01
#  Found R02
# Found BAM:0011
#  Found R01
#  Found R02
# Found BAM:0012
#  Found R01
#  Found R02
# Found BAM:0013
#  Found R01
#  Found R02
# Found BAM:0014
#  Found R01
#  Found R02
# Found BAM:0015
#  Found R01
#  Found R02
# Found BAM:0016
#  Found R01
#  Found R02
# Found BAM:0017
#  Found R01
#  Found R02
# Found BAM:0018
#  Found R01
#  Found R02
# Found BAM:0019
#  Found R01
#  Found R02
# Found BAM:0020
#  Found R01
#  Found R02
# Found BAM:0021
#  Found R01
#  Found R02
# Found BAM:0022
#  Found R01
# Found BAM:0023
#  Found R01
#  Found R02
# Found BAM:0024
#  Found R01
# Found BAM:0025
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0026
#  Found R01
# Found BAM:0027
#  Found R01
# Found BAM:0028
#  Found R01
# Found BAM:0029
#  Found R01
# Found BAM:0030
#  Found R01
# Found BAM:0031
#  Found R01
# Found BAM:0032
#  Found R01
# Found BAM:0033
#  Found R01
# Found BAM:0034
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0035
#  Found R01
#  Found R02
# Found BAM:0036
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0037
#  Found R01
# Found BAM:0038
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0039
#  Found R01
# Found BAM:0040
#  Found R01
# Found BAM:0041
#  Found R01
#  Found R02
# Found BAM:0042
#  Found R01
#  Found R02
# Found BAM:0043
#  Found R01
#  Found R02
# Found BAM:0044
#  Found R01
#  Found R02
# Found BAM:0045
#  Found R01
#  Found R02
# Found BAM:0046
#  Found R01
#  Found R02
# Found BAM:0047
#  Found R01
#  Found R02
# Found BAM:0048
#  Found R01
#  Found R02
# Found BAM:0049
#  Found R01
#  Found R02
# Found BAM:0050
#  Found R01
#  Found R02
# Found BAM:0051
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0052
#  Found R01
#  Found R02
# Found BAM:0053
#  Found R01
#  Found R02
# Found BAM:0054
#  Found R01
#  Found R02
# Found BAM:0055
#  Found R01
#  Found R02
# Found BAM:0056
#  Found R01
#  Found R02
# Found BAM:0057
#  Found R01
#  Found R02
# Found BAM:0058
#  Found R01
#  Found R02
# Found BAM:0059
#  Found R01
#  Found R02
# Found BAM:0060
#  Found R01
#  Found R02
# Found BAM:0061
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0062
#  Found R01
# Found BAM:0063
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0064
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
#  Found R07
#  Found R08
#  Found R09
# Found BAM:0065
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0066
#  Found R01
# Found BAM:0067
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0068
#  Found R01
# Found BAM:0069
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0070
#  Found R01
#  Found R02
# Found BAM:0071
#  Found R01
#  Found R02
# Found BAM:0072
#  Found R01
#  Found R02
# Found BAM:0073
#  Found R01
# Found BAM:0074
#  Found R01
# Found BAM:0075
#  Found R01
# Found BAM:0076
#  Found R01
# Found BAM:0077
#  Found R01
# Found BAM:0078
#  Found R01
# Found BAM:0079
#  Found R01
# Found BAM:0080
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0081
#  Found R01
# Found BAM:0082
#  Found R01
# Found BAM:0083
#  Found R01
# Found BAM:0084
#  Found R01
# Found BAM:0085
#  Found R01
# Found BAM:0086
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
# Found BAM:0087
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0088
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0089
#  Found R01
#  Found R02
# Found BAM:0090
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0091
#  Found R01
#  Found R02
# Found BAM:0092
#  Found R01
#  Found R02
# Found BAM:0093
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0094
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0095
#  Found R01
#  Found R02
# Found BAM:0096
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
#  Found R07
#  Found R08
#  Found R09
#  Found R10
# Found BAM:0097
#  Found R01
# Found BAM:0098
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0099
# File metadata_main.txt not found
#  Found no runs R?? folders in /mnt/c/Users/aashr/Desktop/research/Core_DB_Pytorch_Dataloaders_System/coredldev/_resources/CoRe_DB/BAM_0100
# Found BAM:0100
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0101
#  Found R01
# Found BAM:0102
#  Found R01
#  Found R02
# Found BAM:0103
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0104
#  Found R01
# Found BAM:0105
#  Found R01
# Found BAM:0106
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0107
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0108
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0109
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0110
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0111
#  Found R01
# Found BAM:0112
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0113
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0114
#  Found R01
# Found BAM:0115
#  Found R01
# Found BAM:0116
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0117
#  Found R01
# Found BAM:0118
#  Found R01
# Found BAM:0119
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0120
#  Found R01
# Found BAM:0121
#  Found R01
# Found BAM:0122
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
# Found BAM:0123
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0124
#  Found R01
#  Found R02
# Found BAM:0125
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0126
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0127
#  Found R01
#  Found R02
# Found BAM:0128
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0129
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0130
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0131
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
#  Found R07
#  Found R08
# Found BAM:0132
#  Found R01
#  Found R02
# Found BAM:0133
#  Found R01
#  Found R02
# Found BAM:0134
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0135
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0136
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0137
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0138
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0139
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0140
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0141
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0142
#  Found R01
#  Found R02
# Found BAM:0143
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0144
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0145
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0146
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0147
# skip core_database_index, not a DB key
#  Found R01
# Found THC:0001
#  Found R01
# Found THC:0002
#  Found R01
#  Found R02
# Found THC:0003
#  Found R01
# Found THC:0004
#  Found R01
# Found THC:0005
#  Found R01
#  Found R02
# Found THC:0006
#  Found R01
# Found THC:0007
#  Found R01
# Found THC:0008
#  Found R01
# Found THC:0009
#  Found R01
# Found THC:0010
#  Found R01
# Found THC:0011
#  Found R01
# Found THC:0012
#  Found R01
#  Found R02
# Found THC:0013
#  Found R01
# Found THC:0014
#  Found R01
# Found THC:0015
#  Found R01
#  Found R02
# Found THC:0016
#  Found R01
# Found THC:0017
#  Found R01
# Found THC:0018
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
# Found THC:0019
#  Found R01
# Found THC:0020
#  Found R01
# Found THC:0021
#  Found R01
#  Found R02
#  Found R03
# Found THC:0022
#  Found R01
# Found THC:0023
#  Found R01
# Found THC:0024
#  Found R01
# Found THC:0025
#  Found R01
# Found THC:0026
#  Found R01
# Found THC:0027
#  Found R01
#  Found R02
#  Found R03
# Found THC:0028
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found THC:0029
#  Found R01
#  Found R02
#  Found R03
# Found THC:0030
#  Found R01
# Found THC:0031
#  Found R01
# Found THC:0032
#  Found R01
# Found THC:0033
#  Found R01
# Found THC:0034
#  Found R01
# Found THC:0035
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found THC:0036
#  Found R01
#  Found R02
#  Found R03
# Found THC:0037
#  Found R01
#  Found R02
#  Found R03
# Found THC:0038
#  Found R01
#  Found R02
#  Found R03
# Found THC:0039
#  Found R01
# Found THC:0040
#  Found R01
#  Found R02
# Found THC:0041
#  Found R01
#  Found R02
# Found THC:0042
#  Found R01
#  Found R02
#  Found R03
# Found THC:0043
#  Found R01
#  Found R02
# Found THC:0044
#  Found R01
#  Found R02
# Found THC:0045
#  Found R01
#  Found R02
# Found THC:0046
#  Found R01
#  Found R02
# Found THC:0047
#  Found R01
#  Found R02
# Found THC:0048
#  Found R01
#  Found R02
# Found THC:0049
#  Found R01
#  Found R02
# Found THC:0050
#  Found R01
#  Found R02
# Found THC:0051
#  Found R01
#  Found R02
#  Found R03
# Found THC:0052
#  Found R01
# Found THC:0053
#  Found R01
#  Found R02
#  Found R03
# Found THC:0054
#  Found R01
#  Found R02
# Found THC:0055
#  Found R01
#  Found R02
# Found THC:0056
#  Found R01
#  Found R02
# Found THC:0057
#  Found R01
#  Found R02
# Found THC:0058
#  Found R01
#  Found R02
# Found THC:0059
#  Found R01
#  Found R02
# Found THC:0060
#  Found R01
#  Found R02
# Found THC:0061
#  Found R01
#  Found R02
# Found THC:0062
#  Found R01
#  Found R02
#  Found R03
# Found THC:0063
#  Found R01
#  Found R02
#  Found R03
# Found THC:0064
#  Found R01
# Found THC:0065
#  Found R01
# Found THC:0066
#  Found R01
#  Found R02
# Found THC:0067
#  Found R01
#  Found R02
# Found THC:0068
#  Found R01
#  Found R02
# Found THC:0069
#  Found R01
#  Found R02
# Found THC:0070
#  Found R01
#  Found R02
# Found THC:0071
#  Found R01
#  Found R02
# Found THC:0072
#  Found R01
#  Found R02
# Found THC:0073
#  Found R01
#  Found R02
# Found THC:0074
#  Found R01
#  Found R02
# Found THC:0075
#  Found R01
#  Found R02
# Found THC:0076
#  Found R01
# Found THC:0077
#  Found R01
#  Found R02
#  Found R03
# Found THC:0078
#  Found R01
# Found THC:0079
#  Found R01
# Found THC:0080
#  Found R01
#  Found R02
# Found THC:0081
#  Found R01
#  Found R02
# Found THC:0082
#  Found R01
# Found THC:0083
#  Found R01
#  Found R02
# Found THC:0084
#  Found R01
#  Found R02
# Found THC:0085
#  Found R01
#  Found R02
# Found THC:0086
#  Found R01
# Found THC:0087
#  Found R01
#  Found R02
#  Found R03
# Found THC:0088
#  Found R01
#  Found R02
#  Found R03
# Found THC:0089
#  Found R01
#  Found R02
#  Found R03
# Found THC:0090
#  Found R01
#  Found R02
#  Found R03
# Found THC:0091
#  Found R01
# Found THC:0092
#  Found R01
#  Found R02
# Found THC:0093
#  Found R01
#  Found R02
# Found THC:0094
#  Found R01
# Found THC:0095
#  Found R01
# Found THC:0096
#  Found R01
#  Found R02
# Found THC:0097
#  Found R01
# Found THC:0098
#  Found R01
#  Found R02
# Found THC:0099
#  Found R01
#  Found R02
# Found THC:0100
#  Found R01
# Found THC:0101
#  Found R01
#  Found R02
# Found THC:0102
#  Found R01
#  Found R02
# Found THC:0103
#  Found R01
#  Found R02
# Found THC:0104
#  Found R01
#  Found R02
# Found THC:0105
#  Found R01
#  Found R02
# Found THC:0106
#  Found R01
#  Found R02
# Found THC:0107
# 1
# 1 1 1

# %%
datapoints, eosmap, remaining = h5Finder(shiftpercents=[0],angles=[(0,0,0)],distances = [1]).get_datapoints()
len(datapoints)
# Out:
# Index found, updating...
#
# git-pull core_database_index ...
#
# done!
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0001
#  Found R01
#  Found R02
# Found BAM:0002
#  Found R01
#  Found R02
# Found BAM:0003
#  Found R01
#  Found R02
# Found BAM:0004
#  Found R01
#  Found R02
# Found BAM:0005
#  Found R01
#  Found R02
# Found BAM:0006
#  Found R01
#  Found R02
# Found BAM:0007
#  Found R01
#  Found R02
# Found BAM:0008
#  Found R01
# Found BAM:0009
#  Found R01
#  Found R02
# Found BAM:0010
#  Found R01
#  Found R02
# Found BAM:0011
#  Found R01
#  Found R02
# Found BAM:0012
#  Found R01
#  Found R02
# Found BAM:0013
#  Found R01
#  Found R02
# Found BAM:0014
#  Found R01
#  Found R02
# Found BAM:0015
#  Found R01
#  Found R02
# Found BAM:0016
#  Found R01
#  Found R02
# Found BAM:0017
#  Found R01
#  Found R02
# Found BAM:0018
#  Found R01
#  Found R02
# Found BAM:0019
#  Found R01
#  Found R02
# Found BAM:0020
#  Found R01
#  Found R02
# Found BAM:0021
#  Found R01
#  Found R02
# Found BAM:0022
#  Found R01
# Found BAM:0023
#  Found R01
#  Found R02
# Found BAM:0024
#  Found R01
# Found BAM:0025
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0026
#  Found R01
# Found BAM:0027
#  Found R01
# Found BAM:0028
#  Found R01
# Found BAM:0029
#  Found R01
# Found BAM:0030
#  Found R01
# Found BAM:0031
#  Found R01
# Found BAM:0032
#  Found R01
# Found BAM:0033
#  Found R01
# Found BAM:0034
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0035
#  Found R01
#  Found R02
# Found BAM:0036
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0037
#  Found R01
# Found BAM:0038
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0039
#  Found R01
# Found BAM:0040
#  Found R01
# Found BAM:0041
#  Found R01
#  Found R02
# Found BAM:0042
#  Found R01
#  Found R02
# Found BAM:0043
#  Found R01
#  Found R02
# Found BAM:0044
#  Found R01
#  Found R02
# Found BAM:0045
#  Found R01
#  Found R02
# Found BAM:0046
#  Found R01
#  Found R02
# Found BAM:0047
#  Found R01
#  Found R02
# Found BAM:0048
#  Found R01
#  Found R02
# Found BAM:0049
#  Found R01
#  Found R02
# Found BAM:0050
#  Found R01
#  Found R02
# Found BAM:0051
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0052
#  Found R01
#  Found R02
# Found BAM:0053
#  Found R01
#  Found R02
# Found BAM:0054
#  Found R01
#  Found R02
# Found BAM:0055
#  Found R01
#  Found R02
# Found BAM:0056
#  Found R01
#  Found R02
# Found BAM:0057
#  Found R01
#  Found R02
# Found BAM:0058
#  Found R01
#  Found R02
# Found BAM:0059
#  Found R01
#  Found R02
# Found BAM:0060
#  Found R01
#  Found R02
# Found BAM:0061
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0062
#  Found R01
# Found BAM:0063
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0064
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
#  Found R07
#  Found R08
#  Found R09
# Found BAM:0065
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0066
#  Found R01
# Found BAM:0067
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0068
#  Found R01
# Found BAM:0069
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0070
#  Found R01
#  Found R02
# Found BAM:0071
#  Found R01
#  Found R02
# Found BAM:0072
#  Found R01
#  Found R02
# Found BAM:0073
#  Found R01
# Found BAM:0074
#  Found R01
# Found BAM:0075
#  Found R01
# Found BAM:0076
#  Found R01
# Found BAM:0077
#  Found R01
# Found BAM:0078
#  Found R01
# Found BAM:0079
#  Found R01
# Found BAM:0080
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0081
#  Found R01
# Found BAM:0082
#  Found R01
# Found BAM:0083
#  Found R01
# Found BAM:0084
#  Found R01
# Found BAM:0085
#  Found R01
# Found BAM:0086
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
# Found BAM:0087
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0088
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0089
#  Found R01
#  Found R02
# Found BAM:0090
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0091
#  Found R01
#  Found R02
# Found BAM:0092
#  Found R01
#  Found R02
# Found BAM:0093
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0094
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0095
#  Found R01
#  Found R02
# Found BAM:0096
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
#  Found R07
#  Found R08
#  Found R09
#  Found R10
# Found BAM:0097
#  Found R01
# Found BAM:0098
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0099
# File metadata_main.txt not found
#  Found no runs R?? folders in /mnt/c/Users/aashr/Desktop/research/Core_DB_Pytorch_Dataloaders_System/coredldev/_resources/CoRe_DB/BAM_0100
# Found BAM:0100
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0101
#  Found R01
# Found BAM:0102
#  Found R01
#  Found R02
# Found BAM:0103
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0104
#  Found R01
# Found BAM:0105
#  Found R01
# Found BAM:0106
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0107
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0108
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0109
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0110
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0111
#  Found R01
# Found BAM:0112
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0113
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0114
#  Found R01
# Found BAM:0115
#  Found R01
# Found BAM:0116
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0117
#  Found R01
# Found BAM:0118
#  Found R01
# Found BAM:0119
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0120
#  Found R01
# Found BAM:0121
#  Found R01
# Found BAM:0122
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
# Found BAM:0123
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0124
#  Found R01
#  Found R02
# Found BAM:0125
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0126
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0127
#  Found R01
#  Found R02
# Found BAM:0128
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0129
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0130
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0131
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
#  Found R07
#  Found R08
# Found BAM:0132
#  Found R01
#  Found R02
# Found BAM:0133
#  Found R01
#  Found R02
# Found BAM:0134
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0135
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0136
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
# Found BAM:0137
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0138
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0139
#  Found R01
#  Found R02
#  Found R03
# Found BAM:0140
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0141
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0142
#  Found R01
#  Found R02
# Found BAM:0143
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0144
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0145
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0146
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found BAM:0147
# skip core_database_index, not a DB key
#  Found R01
# Found THC:0001
#  Found R01
# Found THC:0002
#  Found R01
#  Found R02
# Found THC:0003
#  Found R01
# Found THC:0004
#  Found R01
# Found THC:0005
#  Found R01
#  Found R02
# Found THC:0006
#  Found R01
# Found THC:0007
#  Found R01
# Found THC:0008
#  Found R01
# Found THC:0009
#  Found R01
# Found THC:0010
#  Found R01
# Found THC:0011
#  Found R01
# Found THC:0012
#  Found R01
#  Found R02
# Found THC:0013
#  Found R01
# Found THC:0014
#  Found R01
# Found THC:0015
#  Found R01
#  Found R02
# Found THC:0016
#  Found R01
# Found THC:0017
#  Found R01
# Found THC:0018
#  Found R01
#  Found R02
#  Found R03
#  Found R04
#  Found R05
#  Found R06
# Found THC:0019
#  Found R01
# Found THC:0020
#  Found R01
# Found THC:0021
#  Found R01
#  Found R02
#  Found R03
# Found THC:0022
#  Found R01
# Found THC:0023
#  Found R01
# Found THC:0024
#  Found R01
# Found THC:0025
#  Found R01
# Found THC:0026
#  Found R01
# Found THC:0027
#  Found R01
#  Found R02
#  Found R03
# Found THC:0028
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found THC:0029
#  Found R01
#  Found R02
#  Found R03
# Found THC:0030
#  Found R01
# Found THC:0031
#  Found R01
# Found THC:0032
#  Found R01
# Found THC:0033
#  Found R01
# Found THC:0034
#  Found R01
# Found THC:0035
#  Found R01
#  Found R02
#  Found R03
#  Found R04
# Found THC:0036
#  Found R01
#  Found R02
#  Found R03
# Found THC:0037
#  Found R01
#  Found R02
#  Found R03
# Found THC:0038
#  Found R01
#  Found R02
#  Found R03
# Found THC:0039
#  Found R01
# Found THC:0040
#  Found R01
#  Found R02
# Found THC:0041
#  Found R01
#  Found R02
# Found THC:0042
#  Found R01
#  Found R02
#  Found R03
# Found THC:0043
#  Found R01
#  Found R02
# Found THC:0044
#  Found R01
#  Found R02
# Found THC:0045
#  Found R01
#  Found R02
# Found THC:0046
#  Found R01
#  Found R02
# Found THC:0047
#  Found R01
#  Found R02
# Found THC:0048
#  Found R01
#  Found R02
# Found THC:0049
#  Found R01
#  Found R02
# Found THC:0050
#  Found R01
#  Found R02
# Found THC:0051
#  Found R01
#  Found R02
#  Found R03
# Found THC:0052
#  Found R01
# Found THC:0053
#  Found R01
#  Found R02
#  Found R03
# Found THC:0054
#  Found R01
#  Found R02
# Found THC:0055
#  Found R01
#  Found R02
# Found THC:0056
#  Found R01
#  Found R02
# Found THC:0057
#  Found R01
#  Found R02
# Found THC:0058
#  Found R01
#  Found R02
# Found THC:0059
#  Found R01
#  Found R02
# Found THC:0060
#  Found R01
#  Found R02
# Found THC:0061
#  Found R01
#  Found R02
# Found THC:0062
#  Found R01
#  Found R02
#  Found R03
# Found THC:0063
#  Found R01
#  Found R02
#  Found R03
# Found THC:0064
#  Found R01
# Found THC:0065
#  Found R01
# Found THC:0066
#  Found R01
#  Found R02
# Found THC:0067
#  Found R01
#  Found R02
# Found THC:0068
#  Found R01
#  Found R02
# Found THC:0069
#  Found R01
#  Found R02
# Found THC:0070
#  Found R01
#  Found R02
# Found THC:0071
#  Found R01
#  Found R02
# Found THC:0072
#  Found R01
#  Found R02
# Found THC:0073
#  Found R01
#  Found R02
# Found THC:0074
#  Found R01
#  Found R02
# Found THC:0075
#  Found R01
#  Found R02
# Found THC:0076
#  Found R01
# Found THC:0077
#  Found R01
#  Found R02
#  Found R03
# Found THC:0078
#  Found R01
# Found THC:0079
#  Found R01
# Found THC:0080
#  Found R01
#  Found R02
# Found THC:0081
#  Found R01
#  Found R02
# Found THC:0082
#  Found R01
# Found THC:0083
#  Found R01
#  Found R02
# Found THC:0084
#  Found R01
#  Found R02
# Found THC:0085
#  Found R01
#  Found R02
# Found THC:0086
#  Found R01
# Found THC:0087
#  Found R01
#  Found R02
#  Found R03
# Found THC:0088
#  Found R01
#  Found R02
#  Found R03
# Found THC:0089
#  Found R01
#  Found R02
#  Found R03
# Found THC:0090
#  Found R01
#  Found R02
#  Found R03
# Found THC:0091
#  Found R01
# Found THC:0092
#  Found R01
#  Found R02
# Found THC:0093
#  Found R01
#  Found R02
# Found THC:0094
#  Found R01
# Found THC:0095
#  Found R01
# Found THC:0096
#  Found R01
#  Found R02
# Found THC:0097
#  Found R01
# Found THC:0098
#  Found R01
#  Found R02
# Found THC:0099
#  Found R01
#  Found R02
# Found THC:0100
#  Found R01
# Found THC:0101
#  Found R01
#  Found R02
# Found THC:0102
#  Found R01
#  Found R02
# Found THC:0103
#  Found R01
#  Found R02
# Found THC:0104
#  Found R01
#  Found R02
# Found THC:0105
#  Found R01
#  Found R02
# Found THC:0106
#  Found R01
#  Found R02
# Found THC:0107
# 1
# 1 1 1
# 559
